# %% [markdown]
# # Importing Libraries

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\anaconda installer\envs\rp_env\lib\site-packages (3.8.1)
# Requirement already satisfied: click in d:\anaconda installer\envs\rp_env\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in d:\anaconda installer\envs\rp_env\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda installer\envs\rp_env\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in d:\anaconda installer\envs\rp_env\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in d:\anaconda installer\envs\rp_env\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in d:\anaconda installer\envs\rp_env\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in d:\anaconda installer\envs\rp_env\lib\site-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in d:\anaconda installer\envs\rp_env\lib\site-packages (from wordcloud) (10.1.0)
# Requirement already satisfied: matplotlib in d:\anaconda installer\envs\rp_env\lib\site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda installer\envs\rp_env\lib\site-packages (from matplotlib->wordcloud) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda installer\envs\rp_env\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda installer\envs\rp_env\lib\site-packages (from matplotlib->wordcloud) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda installer\envs\rp_env\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda installer\envs\rp_env\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda installer\envs\rp_env\lib\site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda installer\envs\rp_env\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda installer\envs\rp_env\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import nltk
import random
from nltk.corpus import stopwords
from nltk import bigrams, FreqDist, word_tokenize
from nltk.probability import ConditionalFreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Piyush
# [nltk_data]     Sharma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Piyush Sharma\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# # Importing Book

# %% [markdown]
# Import and read the book in .txt format

# %%
with open('output_new.txt', 'r', encoding='utf8') as file:
    book_text = file.read()

# %% [markdown]
# # Text Pre-Processing

# %% [markdown]
# Remove chapter names,chapter numbers, pictures, tables etc.

# %%
cleaned_text = re.sub(r'\b(Chapter [IVXLCDM]+|Chapter [0-9]+|Figure [0-9]+)\b', '', book_text)

# %% [markdown]
# # Tokenization

# %% [markdown]
# Tokenize cleaned_text and remove stop words

# %%
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(cleaned_text.lower())
filtered_tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
filtered_tokens
# Out:
# ['book',
#  'seek',
#  'ye',
#  'shall',
#  'words',
#  'echoing',
#  'head',
#  'eminent',
#  'harvard',
#  'symbologist',
#  'robert',
#  'langdon',
#  'awakes',
#  'hospital',
#  'bed',
#  'recollection',
#  'got',
#  'explain',
#  'origin',
#  'macabre',
#  'object',
#  'found',
#  'hidden',
#  'belongings',
#  'threat',
#  'life',
#  'propel',
#  'young',
#  'doctor',
#  'sienna',
#  'brooks',
#  'breakneck',
#  'chase',
#  'across',
#  'city',
#  'florence',
#  'langdon',
#  'knowledge',
#  'hidden',
#  'passageways',
#  'ancient',
#  'secrets',
#  'lie',
#  'behind',
#  'historic',
#  'facade',
#  'save',
#  'clutches',
#  'unknown',
#  'pursuers',
#  'lines',
#  'dante',
#  'dark',
#  'epic',
#  'masterpiece',
#  'inferno',
#  'guide',
#  'must',
#  'decipher',
#  'sequence',
#  'codes',
#  'buried',
#  'deep',
#  'within',
#  'celebrated',
#  'artefacts',
#  'renaissance',
#  'sculptures',
#  'paintings',
#  'buildings',
#  'find',
#  'answers',
#  'puzzle',
#  'may',
#  'may',
#  'help',
#  'save',
#  'world',
#  'terrifying',
#  'set',
#  'extraordinary',
#  'landscape',
#  'inspired',
#  'one',
#  'history',
#  'ominous',
#  'literary',
#  'classics',
#  'inferno',
#  'dan',
#  'brown',
#  'compelling',
#  'novel',
#  'yet',
#  'breathless',
#  'thriller',
#  'grab',
#  'page',
#  'one',
#  'let',
#  'go',
#  'close',
#  'cover',
#  'book',
#  'title',
#  'page',
#  'dedication',
#  'acknowledgments',
#  'epigraph',
#  'fact',
#  'prologue',
#  'epilogue',
#  'author',
#  'also',
#  'dan',
#  'brown',
#  'copyrightfor',
#  'parents',
#  'humble',
#  'sincere',
#  'thanks',
#  'always',
#  'first',
#  'foremost',
#  'editor',
#  'close',
#  'friend',
#  'jason',
#  'kaufman',
#  'dedication',
#  'talent',
#  'mainly',
#  'endless',
#  'good',
#  'humor',
#  'extraordinary',
#  'wife',
#  'blythe',
#  'love',
#  'patience',
#  'writing',
#  'process',
#  'also',
#  'superb',
#  'instincts',
#  'candor',
#  'editor',
#  'tireless',
#  'agent',
#  'trusted',
#  'friend',
#  'heide',
#  'lange',
#  'expertly',
#  'navigating',
#  'conversations',
#  'countries',
#  'topics',
#  'ever',
#  'know',
#  'skills',
#  'energy',
#  'eternally',
#  'grateful',
#  'entire',
#  'team',
#  'doubleday',
#  'enthusiasm',
#  'creativity',
#  'efforts',
#  'behalf',
#  'books',
#  'special',
#  'thanks',
#  'suzanne',
#  'herz',
#  'wearing',
#  'many',
#  'hats',
#  'wearing',
#  'well',
#  'bill',
#  'thomas',
#  'michael',
#  'windsor',
#  'judy',
#  'jacoby',
#  'joe',
#  'gallagher',
#  'rob',
#  'bloom',
#  'nora',
#  'reichard',
#  'beth',
#  'meister',
#  'maria',
#  'carella',
#  'lorraine',
#  'hyland',
#  'also',
#  'unending',
#  'support',
#  'sonny',
#  'mehta',
#  'tony',
#  'chirico',
#  'kathy',
#  'trager',
#  'anne',
#  'messitte',
#  'markus',
#  'dohle',
#  'incredible',
#  'people',
#  'random',
#  'house',
#  'sales',
#  'department',
#  'unrivaled',
#  'sage',
#  'counsel',
#  'michael',
#  'rudell',
#  'instincts',
#  'matters',
#  'large',
#  'small',
#  'well',
#  'friendship',
#  'irreplaceable',
#  'assistant',
#  'susan',
#  'morehouse',
#  'grace',
#  'vitality',
#  'without',
#  'things',
#  'descend',
#  'chaos',
#  'friends',
#  'transworld',
#  'particular',
#  'bill',
#  'creativity',
#  'support',
#  'good',
#  'cheer',
#  'also',
#  'gail',
#  'rebuck',
#  'superb',
#  'leadership',
#  'italian',
#  'publisher',
#  'mondadori',
#  'especially',
#  'ricky',
#  'cavallero',
#  'piera',
#  'cusani',
#  'giovanni',
#  'dutto',
#  'antonio',
#  'franchini',
#  'claudia',
#  'scheu',
#  'turkish',
#  'publisher',
#  'altin',
#  'kitaplar',
#  'particularly',
#  'oya',
#  'alpar',
#  'erden',
#  'heper',
#  'batu',
#  'bozkurt',
#  'special',
#  'services',
#  'provided',
#  'connection',
#  'locations',
#  'book',
#  'exceptional',
#  'publishers',
#  'around',
#  'world',
#  'passion',
#  'hard',
#  'work',
#  'commitment',
#  'impressive',
#  'management',
#  'london',
#  'milan',
#  'translation',
#  'sites',
#  'leon',
#  'luciano',
#  'guglielmi',
#  'bright',
#  'marta',
#  'alvarez',
#  'gonzález',
#  'spending',
#  'much',
#  'time',
#  'us',
#  'florence',
#  'bringing',
#  'life',
#  'city',
#  'art',
#  'architecture',
#  'peerless',
#  'maurizio',
#  'pimponi',
#  'enhance',
#  'visit',
#  'italy',
#  'historians',
#  'guides',
#  'specialists',
#  'generously',
#  'spent',
#  'time',
#  'florence',
#  'venice',
#  'sharing',
#  'expertise',
#  'giovanna',
#  'rao',
#  'eugenia',
#  'antonucci',
#  'biblioteca',
#  'medicea',
#  'laurenziana',
#  'serena',
#  'pini',
#  'staff',
#  'palazzo',
#  'vecchio',
#  'giovanna',
#  'giusti',
#  'uffizi',
#  'gallery',
#  'barbara',
#  'fedeli',
#  'baptistery',
#  'il',
#  'duomo',
#  'ettore',
#  'vito',
#  'massimo',
#  'bisson',
#  'mark',
#  'basilica',
#  'giorgio',
#  'tagliaferro',
#  'doge',
#  'palace',
#  'isabella',
#  'di',
#  'lenardo',
#  'elizabeth',
#  'carroll',
#  'consavari',
#  'elena',
#  'svalduz',
#  'throughout',
#  'venice',
#  'annalisa',
#  'bruni',
#  'staff',
#  'biblioteca',
#  'nazionale',
#  'marciana',
#  'many',
#  'others',
#  'vefailed',
#  'mention',
#  'abbreviated',
#  'list',
#  'sincere',
#  'thanks',
#  'rachael',
#  'dillon',
#  'fried',
#  'stephanie',
#  'delman',
#  'sanford',
#  'greenburger',
#  'associates',
#  'everything',
#  'abroad',
#  'exceptional',
#  'minds',
#  'george',
#  'abraham',
#  'john',
#  'treanor',
#  'bob',
#  'helm',
#  'scientific',
#  'expertise',
#  'early',
#  'readers',
#  'provided',
#  'perspective',
#  'along',
#  'way',
#  'greg',
#  'brown',
#  'dick',
#  'connie',
#  'brown',
#  'rebecca',
#  'kaufman',
#  'jerry',
#  'olivia',
#  'kaufman',
#  'john',
#  'chaffee',
#  'alex',
#  'cannon',
#  'along',
#  'team',
#  'sanborn',
#  'media',
#  'factory',
#  'keeps',
#  'things',
#  'humming',
#  'online',
#  'world',
#  'judd',
#  'kathy',
#  'gregg',
#  'providing',
#  'quiet',
#  'sanctuary',
#  'within',
#  'green',
#  'gables',
#  'wrote',
#  'final',
#  'chapters',
#  'book',
#  'superb',
#  'online',
#  'resources',
#  'princeton',
#  'dante',
#  'project',
#  'digital',
#  'dante',
#  'columbia',
#  'university',
#  'world',
#  'darkest',
#  'places',
#  'hell',
#  'reserved',
#  'maintain',
#  'neutrality',
#  'times',
#  'moral',
#  'crisis',
#  'fact',
#  'artwork',
#  'literature',
#  'science',
#  'historical',
#  'references',
#  'novel',
#  'real',
#  'consortium',
#  'private',
#  'organization',
#  'offices',
#  'seven',
#  'countries',
#  'name',
#  'changed',
#  'considerations',
#  'security',
#  'privacy',
#  'inferno',
#  'underworld',
#  'described',
#  'dante',
#  'alighieri',
#  'epic',
#  'poem',
#  'divine',
#  'comedy',
#  'portrays',
#  'hell',
#  'elaborately',
#  'structured',
#  'realm',
#  'populated',
#  'entities',
#  'known',
#  'shades',
#  'souls',
#  'trapped',
#  'life',
#  'death',
#  'prologue',
#  'shade',
#  'dolent',
#  'city',
#  'flee',
#  'eternal',
#  'woe',
#  'take',
#  'flight',
#  'along',
#  'banks',
#  'river',
#  'arno',
#  'scramble',
#  'breathless',
#  'turning',
#  'left',
#  'onto',
#  'via',
#  'dei',
#  'castellani',
#  'making',
#  'way',
#  'northward',
#  'huddling',
#  'shadows',
#  'uffizi',
#  'still',
#  'pursue',
#  'footsteps',
#  'grow',
#  'louder',
#  'hunt',
#  'relentless',
#  'determination',
#  'years',
#  'pursued',
#  'persistence',
#  'kept',
#  'underground',
#  'forced',
#  'live',
#  'purgatory',
#  'laboring',
#  'beneath',
#  'earth',
#  'like',
#  'chthonic',
#  'monster',
#  'shade',
#  'aboveground',
#  'raise',
#  'eyes',
#  'north',
#  'unable',
#  'find',
#  'direct',
#  'path',
#  'salvation',
#  'apennine',
#  'mountains',
#  'blotting',
#  'first',
#  'light',
#  'dawn',
#  'pass',
#  'behind',
#  'palazzo',
#  'crenellated',
#  'tower',
#  'clock',
#  'snaking',
#  'vendors',
#  'piazza',
#  'di',
#  'san',
#  'firenze',
#  'hoarse',
#  'voices',
#  'smelling',
#  'lampredotto',
#  'roasted',
#  'olives',
#  'crossing',
#  'bargello',
#  'cut',
#  'west',
#  'toward',
#  'spire',
#  'badia',
#  'come',
#  'hard',
#  'iron',
#  'gate',
#  'base',
#  'stairs',
#  'hesitation',
#  'must',
#  'left',
#  'behind',
#  'turn',
#  'handle',
#  'step',
#  'passage',
#  'know',
#  'return',
#  'urge',
#  'leaden',
#  'legs',
#  'narrow',
#  'staircase',
#  'spiraling',
#  'skyward',
#  'soft',
#  'marble',
#  'treads',
#  'pitted',
#  'worn',
#  'voices',
#  'echo',
#  'beseeching',
#  'behind',
#  'unyielding',
#  'closing',
#  'understand',
#  'coming',
#  'done',
#  'ungrateful',
#  'land',
#  'climb',
#  'visions',
#  'come',
#  'hard',
#  'lustful',
#  'bodies',
#  'writhing',
#  'fiery',
#  'rain',
#  'gluttonous',
#  'souls',
#  'floating',
#  'excrement',
#  'treacherous',
#  'villains',
#  'frozen',
#  'satan',
#  'icy',
#  'grasp',
#  'climb',
#  'final',
#  'stairs',
#  'arrive',
#  'top',
#  'staggering',
#  'near',
#  'dead',
#  'damp',
#  'morning',
#  'air',
#  'rush',
#  'wall',
#  'peering',
#  'slits',
#  'far',
#  'blessed',
#  'city',
#  'made',
#  'sanctuary',
#  'exiled',
#  'voices',
#  'call',
#  'arriving',
#  'close',
#  'behind',
#  'done',
#  'madness',
#  'madness',
#  'breeds',
#  'madness',
#  'love',
#  'god',
#  'shout',
#  'tell',
#  'us',
#  'hidden',
#  'precisely',
#  'love',
#  'god',
#  'stand',
#  'cornered',
#  'back',
#  'cold',
#  'stone',
#  'stare',
#  'deep',
#  'clear',
#  'green',
#  'eyes',
#  'expressions',
#  'darken',
#  'longer',
#  'cajoling',
#  'threatening',
#  'know',
#  'methods',
#  'force',
#  'tell',
#  'us',
#  'reason',
#  'climbed',
#  'halfway',
#  'heaven',
#  'without',
#  'warning',
#  'turn',
#  'reach',
#  'curling',
#  'fingers',
#  'onto',
#  'high',
#  'ledge',
#  'pulling',
#  'scrambling',
#  'onto',
#  'knees',
#  'standing',
#  'unsteady',
#  'precipice',
#  'guideme',
#  'dear',
#  'virgil',
#  'across',
#  'void',
#  'rush',
#  'forward',
#  'disbelief',
#  'wanting',
#  'grab',
#  'feet',
#  'fearing',
#  'upset',
#  'balance',
#  'knock',
#  'beg',
#  'quiet',
#  'desperation',
#  'turned',
#  'back',
#  'know',
#  'must',
#  'beneath',
#  'dizzyingly',
#  'far',
#  'beneath',
#  'red',
#  'tile',
#  'roofs',
#  'spread',
#  'like',
#  'sea',
#  'fire',
#  'countryside',
#  'illuminating',
#  'fair',
#  'land',
#  'upon',
#  'giants',
#  'roamed',
#  'giotto',
#  'donatello',
#  'brunelleschi',
#  'michelangelo',
#  'botticelli',
#  'inch',
#  'toes',
#  'edge',
#  'come',
#  'shout',
#  'late',
#  'willful',
#  'ignorants',
#  'see',
#  'future',
#  'grasp',
#  'splendor',
#  'creation',
#  'necessity',
#  'gladly',
#  'make',
#  'ultimate',
#  'sacrifice',
#  'extinguish',
#  'final',
#  'hope',
#  'finding',
#  'seek',
#  'never',
#  'locate',
#  'time',
#  'hundreds',
#  'feet',
#  'cobblestone',
#  'piazza',
#  'beckons',
#  'like',
#  'tranquil',
#  'oasis',
#  'long',
#  'time',
#  'time',
#  'one',
#  'commodity',
#  'even',
#  'vast',
#  'fortunes',
#  'afford',
#  'final',
#  'seconds',
#  'gaze',
#  'piazza',
#  'behold',
#  'sight',
#  'startles',
#  'see',
#  'face',
#  'gazing',
#  'shadows',
#  'eyes',
#  'mournful',
#  'yet',
#  'sense',
#  'veneration',
#  'accomplished',
#  'understand',
#  'choice',
#  'love',
#  'mankind',
#  'must',
#  'protect',
#  'masterpiece',
#  'grows',
#  'even',
#  'waiting',
#  'simmering',
#  'beneath',
#  'bloodred',
#  'waters',
#  'lagoon',
#  'reflects',
#  'stars',
#  'lift',
#  'eyes',
#  'contemplate',
#  'horizon',
#  'high',
#  'burdened',
#  'world',
#  'make',
#  'final',
#  'supplication',
#  'dearest',
#  'god',
#  'pray',
#  'world',
#  'remembers',
#  'name',
#  'monstrous',
#  'sinner',
#  'glorious',
#  'savior',
#  'know',
#  'truly',
#  'pray',
#  'mankind',
#  'understand',
#  'gift',
#  'leave',
#  'behind',
#  'gift',
#  'future',
#  'gift',
#  'salvation',
#  'gift',
#  'inferno',
#  'whisper',
#  'amen',
#  'take',
#  'final',
#  'step',
#  'abyss',
#  'chapter',
#  'memories',
#  'materialized',
#  'slowly',
#  'like',
#  'bubbles',
#  'surfacing',
#  'darkness',
#  'bottomless',
#  'well',
#  'veiled',
#  'woman',
#  'robert',
#  'langdon',
#  'gazed',
#  'across',
#  'river',
#  'whose',
#  'churning',
#  'waters',
#  'ran',
#  'red',
#  'blood',
#  'far',
#  'bank',
#  'woman',
#  'stood',
#  'facing',
#  'motionless',
#  'solemn',
#  'face',
#  'hidden',
#  'shroud',
#  'hand',
#  'gripped',
#  'blue',
#  'tainia',
#  'cloth',
#  'raised',
#  'honor',
#  'sea',
#  'corpses',
#  'feet',
#  'smell',
#  'death',
#  'hung',
#  'everywhere',
#  'seek',
#  'woman',
#  'whispered',
#  'ye',
#  'shall',
#  'find',
#  'langdon',
#  'heard',
#  'words',
#  'spoken',
#  'inside',
#  'head',
#  'called',
#  'voice',
#  'made',
#  'sound',
#  'time',
#  'grows',
#  'short',
#  'whispered',
#  'seek',
#  'find',
#  'langdon',
#  'took',
#  'step',
#  'toward',
#  'river',
#  'could',
#  'see',
#  'waters',
#  'bloodred',
#  'deep',
#  'traverse',
#  'langdon',
#  'raised',
#  'eyes',
#  'veiled',
#  'woman',
#  'bodies',
#  'feet',
#  'multiplied',
#  'hundreds',
#  'maybe',
#  'thousands',
#  'still',
#  'alive',
#  'writhing',
#  'agony',
#  'dying',
#  'unthinkable',
#  'deaths',
#  'consumed',
#  'fire',
#  'buried',
#  ...]

# %% [markdown]
# # Frequency Distribution

# %%
token_freq_dist = FreqDist(filtered_tokens)
token_freq_dist
# Out:
# FreqDist({'langdon': 2158, 'sienna': 986, 'said': 507, 'sinskey': 364, 'could': 336, 'one': 325, 'man': 321, 'back': 313, 'eyes': 295, 'would': 294, ...})

# %% [markdown]
# # Word Cloud

# %%
wordcloud = WordCloud(width=800, height=400).generate_from_frequencies(token_freq_dist)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # POS Tagging

# %% [markdown]
# By default 'pos_tag' function use "Penn Treebank" tagset

# %%
pos_tags = nltk.pos_tag(filtered_tokens) 
pos_tags
# Out:
# [('book', 'NN'),
#  ('seek', 'NN'),
#  ('ye', 'NN'),
#  ('shall', 'MD'),
#  ('words', 'NNS'),
#  ('echoing', 'VBG'),
#  ('head', 'NN'),
#  ('eminent', 'JJ'),
#  ('harvard', 'JJ'),
#  ('symbologist', 'NN'),
#  ('robert', 'NN'),
#  ('langdon', 'NN'),
#  ('awakes', 'NNS'),
#  ('hospital', 'VBP'),
#  ('bed', 'JJ'),
#  ('recollection', 'NN'),
#  ('got', 'VBD'),
#  ('explain', 'JJ'),
#  ('origin', 'NN'),
#  ('macabre', 'NN'),
#  ('object', 'VBP'),
#  ('found', 'VBN'),
#  ('hidden', 'JJ'),
#  ('belongings', 'NNS'),
#  ('threat', 'NN'),
#  ('life', 'NN'),
#  ('propel', 'VB'),
#  ('young', 'JJ'),
#  ('doctor', 'NN'),
#  ('sienna', 'NN'),
#  ('brooks', 'VBZ'),
#  ('breakneck', 'JJ'),
#  ('chase', 'JJ'),
#  ('across', 'IN'),
#  ('city', 'NN'),
#  ('florence', 'NN'),
#  ('langdon', 'VBD'),
#  ('knowledge', 'NN'),
#  ('hidden', 'NN'),
#  ('passageways', 'NNS'),
#  ('ancient', 'JJ'),
#  ('secrets', 'NNS'),
#  ('lie', 'VBP'),
#  ('behind', 'IN'),
#  ('historic', 'JJ'),
#  ('facade', 'NN'),
#  ('save', 'NN'),
#  ('clutches', 'NNS'),
#  ('unknown', 'JJ'),
#  ('pursuers', 'NNS'),
#  ('lines', 'NNS'),
#  ('dante', 'VBP'),
#  ('dark', 'JJ'),
#  ('epic', 'NN'),
#  ('masterpiece', 'NN'),
#  ('inferno', 'NN'),
#  ('guide', 'NN'),
#  ('must', 'MD'),
#  ('decipher', 'VB'),
#  ('sequence', 'NN'),
#  ('codes', 'NNS'),
#  ('buried', 'VBD'),
#  ('deep', 'JJ'),
#  ('within', 'IN'),
#  ('celebrated', 'JJ'),
#  ('artefacts', 'NNS'),
#  ('renaissance', 'NN'),
#  ('sculptures', 'VBZ'),
#  ('paintings', 'NNS'),
#  ('buildings', 'NNS'),
#  ('find', 'VBP'),
#  ('answers', 'NNS'),
#  ('puzzle', 'VBP'),
#  ('may', 'MD'),
#  ('may', 'MD'),
#  ('help', 'VB'),
#  ('save', 'VB'),
#  ('world', 'NN'),
#  ('terrifying', 'VBG'),
#  ('set', 'VBN'),
#  ('extraordinary', 'JJ'),
#  ('landscape', 'NN'),
#  ('inspired', 'VBD'),
#  ('one', 'CD'),
#  ('history', 'NN'),
#  ('ominous', 'JJ'),
#  ('literary', 'JJ'),
#  ('classics', 'NNS'),
#  ('inferno', 'VBP'),
#  ('dan', 'JJ'),
#  ('brown', 'IN'),
#  ('compelling', 'VBG'),
#  ('novel', 'JJ'),
#  ('yet', 'RB'),
#  ('breathless', 'JJ'),
#  ('thriller', 'NN'),
#  ('grab', 'NN'),
#  ('page', 'NN'),
#  ('one', 'CD'),
#  ('let', 'NN'),
#  ('go', 'VB'),
#  ('close', 'RB'),
#  ('cover', 'JJ'),
#  ('book', 'NN'),
#  ('title', 'JJ'),
#  ('page', 'NN'),
#  ('dedication', 'NN'),
#  ('acknowledgments', 'NNS'),
#  ('epigraph', 'VBP'),
#  ('fact', 'NN'),
#  ('prologue', 'NN'),
#  ('epilogue', 'NN'),
#  ('author', 'NN'),
#  ('also', 'RB'),
#  ('dan', 'VBZ'),
#  ('brown', 'JJ'),
#  ('copyrightfor', 'JJ'),
#  ('parents', 'NNS'),
#  ('humble', 'JJ'),
#  ('sincere', 'JJ'),
#  ('thanks', 'NNS'),
#  ('always', 'RB'),
#  ('first', 'RB'),
#  ('foremost', 'VBN'),
#  ('editor', 'NN'),
#  ('close', 'JJ'),
#  ('friend', 'NN'),
#  ('jason', 'NN'),
#  ('kaufman', 'JJ'),
#  ('dedication', 'NN'),
#  ('talent', 'NN'),
#  ('mainly', 'RB'),
#  ('endless', 'RB'),
#  ('good', 'JJ'),
#  ('humor', 'NN'),
#  ('extraordinary', 'JJ'),
#  ('wife', 'NN'),
#  ('blythe', 'NN'),
#  ('love', 'NN'),
#  ('patience', 'NN'),
#  ('writing', 'VBG'),
#  ('process', 'NN'),
#  ('also', 'RB'),
#  ('superb', 'VBZ'),
#  ('instincts', 'NNS'),
#  ('candor', 'NN'),
#  ('editor', 'NN'),
#  ('tireless', 'NN'),
#  ('agent', 'NN'),
#  ('trusted', 'VBD'),
#  ('friend', 'JJ'),
#  ('heide', 'NN'),
#  ('lange', 'NN'),
#  ('expertly', 'RB'),
#  ('navigating', 'JJ'),
#  ('conversations', 'NNS'),
#  ('countries', 'NNS'),
#  ('topics', 'NNS'),
#  ('ever', 'RB'),
#  ('know', 'VBP'),
#  ('skills', 'NNS'),
#  ('energy', 'NN'),
#  ('eternally', 'RB'),
#  ('grateful', 'JJ'),
#  ('entire', 'JJ'),
#  ('team', 'NN'),
#  ('doubleday', 'NN'),
#  ('enthusiasm', 'VBP'),
#  ('creativity', 'NN'),
#  ('efforts', 'NNS'),
#  ('behalf', 'NN'),
#  ('books', 'NNS'),
#  ('special', 'JJ'),
#  ('thanks', 'NNS'),
#  ('suzanne', 'VBP'),
#  ('herz', 'JJ'),
#  ('wearing', 'VBG'),
#  ('many', 'JJ'),
#  ('hats', 'NNS'),
#  ('wearing', 'VBG'),
#  ('well', 'RB'),
#  ('bill', 'NN'),
#  ('thomas', 'VBZ'),
#  ('michael', 'RBS'),
#  ('windsor', 'NN'),
#  ('judy', 'NN'),
#  ('jacoby', 'NN'),
#  ('joe', 'NN'),
#  ('gallagher', 'NN'),
#  ('rob', 'NN'),
#  ('bloom', 'NN'),
#  ('nora', 'RB'),
#  ('reichard', 'JJ'),
#  ('beth', 'NN'),
#  ('meister', 'NN'),
#  ('maria', 'NN'),
#  ('carella', 'NN'),
#  ('lorraine', 'NN'),
#  ('hyland', 'NN'),
#  ('also', 'RB'),
#  ('unending', 'JJ'),
#  ('support', 'NN'),
#  ('sonny', 'VBD'),
#  ('mehta', 'NNS'),
#  ('tony', 'JJ'),
#  ('chirico', 'NN'),
#  ('kathy', 'NN'),
#  ('trager', 'NN'),
#  ('anne', 'VBP'),
#  ('messitte', 'NN'),
#  ('markus', 'NN'),
#  ('dohle', 'VBZ'),
#  ('incredible', 'JJ'),
#  ('people', 'NNS'),
#  ('random', 'VBP'),
#  ('house', 'NN'),
#  ('sales', 'NNS'),
#  ('department', 'NN'),
#  ('unrivaled', 'JJ'),
#  ('sage', 'NN'),
#  ('counsel', 'NN'),
#  ('michael', 'NN'),
#  ('rudell', 'VBP'),
#  ('instincts', 'VBZ'),
#  ('matters', 'NNS'),
#  ('large', 'JJ'),
#  ('small', 'JJ'),
#  ('well', 'RB'),
#  ('friendship', 'JJ'),
#  ('irreplaceable', 'JJ'),
#  ('assistant', 'NN'),
#  ('susan', 'NN'),
#  ('morehouse', 'NN'),
#  ('grace', 'NN'),
#  ('vitality', 'NN'),
#  ('without', 'IN'),
#  ('things', 'NNS'),
#  ('descend', 'VBP'),
#  ('chaos', 'JJ'),
#  ('friends', 'NNS'),
#  ('transworld', 'VBP'),
#  ('particular', 'JJ'),
#  ('bill', 'NN'),
#  ('creativity', 'NN'),
#  ('support', 'NN'),
#  ('good', 'JJ'),
#  ('cheer', 'NN'),
#  ('also', 'RB'),
#  ('gail', 'JJ'),
#  ('rebuck', 'NN'),
#  ('superb', 'JJ'),
#  ('leadership', 'NN'),
#  ('italian', 'JJ'),
#  ('publisher', 'NN'),
#  ('mondadori', 'NN'),
#  ('especially', 'RB'),
#  ('ricky', 'JJ'),
#  ('cavallero', 'NN'),
#  ('piera', 'NN'),
#  ('cusani', 'NN'),
#  ('giovanni', 'NN'),
#  ('dutto', 'NN'),
#  ('antonio', 'NN'),
#  ('franchini', 'JJ'),
#  ('claudia', 'NN'),
#  ('scheu', 'NN'),
#  ('turkish', 'NN'),
#  ('publisher', 'NN'),
#  ('altin', 'JJ'),
#  ('kitaplar', 'JJ'),
#  ('particularly', 'RB'),
#  ('oya', 'JJ'),
#  ('alpar', 'NN'),
#  ('erden', 'JJ'),
#  ('heper', 'NN'),
#  ('batu', 'NN'),
#  ('bozkurt', 'NN'),
#  ('special', 'JJ'),
#  ('services', 'NNS'),
#  ('provided', 'VBN'),
#  ('connection', 'NN'),
#  ('locations', 'NNS'),
#  ('book', 'NN'),
#  ('exceptional', 'JJ'),
#  ('publishers', 'NNS'),
#  ('around', 'IN'),
#  ('world', 'NN'),
#  ('passion', 'NN'),
#  ('hard', 'JJ'),
#  ('work', 'NN'),
#  ('commitment', 'NN'),
#  ('impressive', 'JJ'),
#  ('management', 'NN'),
#  ('london', 'NN'),
#  ('milan', 'NN'),
#  ('translation', 'NN'),
#  ('sites', 'VBZ'),
#  ('leon', 'JJ'),
#  ('luciano', 'NN'),
#  ('guglielmi', 'NN'),
#  ('bright', 'VBD'),
#  ('marta', 'JJ'),
#  ('alvarez', 'NN'),
#  ('gonzález', 'NN'),
#  ('spending', 'NN'),
#  ('much', 'JJ'),
#  ('time', 'NN'),
#  ('us', 'PRP'),
#  ('florence', 'VB'),
#  ('bringing', 'VBG'),
#  ('life', 'NN'),
#  ('city', 'NN'),
#  ('art', 'NN'),
#  ('architecture', 'NN'),
#  ('peerless', 'NN'),
#  ('maurizio', 'NN'),
#  ('pimponi', 'NN'),
#  ('enhance', 'NN'),
#  ('visit', 'NN'),
#  ('italy', 'NN'),
#  ('historians', 'NNS'),
#  ('guides', 'VBP'),
#  ('specialists', 'NNS'),
#  ('generously', 'RB'),
#  ('spent', 'JJ'),
#  ('time', 'NN'),
#  ('florence', 'NN'),
#  ('venice', 'NN'),
#  ('sharing', 'VBG'),
#  ('expertise', 'NN'),
#  ('giovanna', 'NN'),
#  ('rao', 'NN'),
#  ('eugenia', 'NN'),
#  ('antonucci', 'NN'),
#  ('biblioteca', 'NN'),
#  ('medicea', 'NN'),
#  ('laurenziana', 'FW'),
#  ('serena', 'NN'),
#  ('pini', 'NN'),
#  ('staff', 'NN'),
#  ('palazzo', 'NN'),
#  ('vecchio', 'NN'),
#  ('giovanna', 'NN'),
#  ('giusti', 'NN'),
#  ('uffizi', 'JJ'),
#  ('gallery', 'NN'),
#  ('barbara', 'NN'),
#  ('fedeli', 'JJ'),
#  ('baptistery', 'NN'),
#  ('il', 'NN'),
#  ('duomo', 'NN'),
#  ('ettore', 'NN'),
#  ('vito', 'NN'),
#  ('massimo', 'NN'),
#  ('bisson', 'NN'),
#  ('mark', 'NN'),
#  ('basilica', 'NN'),
#  ('giorgio', 'NN'),
#  ('tagliaferro', 'NN'),
#  ('doge', 'NN'),
#  ('palace', 'NN'),
#  ('isabella', 'NN'),
#  ('di', 'NN'),
#  ('lenardo', 'NN'),
#  ('elizabeth', 'VBZ'),
#  ('carroll', 'NN'),
#  ('consavari', 'NN'),
#  ('elena', 'NN'),
#  ('svalduz', 'NN'),
#  ('throughout', 'IN'),
#  ('venice', 'NN'),
#  ('annalisa', 'NNS'),
#  ('bruni', 'JJ'),
#  ('staff', 'NN'),
#  ('biblioteca', 'NN'),
#  ('nazionale', 'JJ'),
#  ('marciana', 'VBD'),
#  ('many', 'JJ'),
#  ('others', 'NNS'),
#  ('vefailed', 'VBD'),
#  ('mention', 'NN'),
#  ('abbreviated', 'VBN'),
#  ('list', 'NN'),
#  ('sincere', 'JJ'),
#  ('thanks', 'NNS'),
#  ('rachael', 'VBP'),
#  ('dillon', 'NN'),
#  ('fried', 'VBN'),
#  ('stephanie', 'JJ'),
#  ('delman', 'NN'),
#  ('sanford', 'NN'),
#  ('greenburger', 'NN'),
#  ('associates', 'VBZ'),
#  ('everything', 'NN'),
#  ('abroad', 'RB'),
#  ('exceptional', 'JJ'),
#  ('minds', 'NNS'),
#  ('george', 'VBP'),
#  ('abraham', 'JJ'),
#  ('john', 'NN'),
#  ('treanor', 'NN'),
#  ('bob', 'NN'),
#  ('helm', 'NN'),
#  ('scientific', 'JJ'),
#  ('expertise', 'NN'),
#  ('early', 'JJ'),
#  ('readers', 'NNS'),
#  ('provided', 'VBD'),
#  ('perspective', 'NN'),
#  ('along', 'IN'),
#  ('way', 'NN'),
#  ('greg', 'JJ'),
#  ('brown', 'JJ'),
#  ('dick', 'NN'),
#  ('connie', 'NN'),
#  ('brown', 'IN'),
#  ('rebecca', 'JJ'),
#  ('kaufman', 'NN'),
#  ('jerry', 'NN'),
#  ('olivia', 'JJ'),
#  ('kaufman', 'NN'),
#  ('john', 'NN'),
#  ('chaffee', 'NN'),
#  ('alex', 'JJ'),
#  ('cannon', 'NN'),
#  ('along', 'IN'),
#  ('team', 'NN'),
#  ('sanborn', 'VBN'),
#  ('media', 'NNS'),
#  ('factory', 'JJ'),
#  ('keeps', 'NNS'),
#  ('things', 'NNS'),
#  ('humming', 'VBG'),
#  ('online', 'JJ'),
#  ('world', 'NN'),
#  ('judd', 'NN'),
#  ('kathy', 'NN'),
#  ('gregg', 'NN'),
#  ('providing', 'VBG'),
#  ('quiet', 'JJ'),
#  ('sanctuary', 'NN'),
#  ('within', 'IN'),
#  ('green', 'JJ'),
#  ('gables', 'NNS'),
#  ('wrote', 'VBD'),
#  ('final', 'JJ'),
#  ('chapters', 'NNS'),
#  ('book', 'NN'),
#  ('superb', 'VBP'),
#  ('online', 'JJ'),
#  ('resources', 'NNS'),
#  ('princeton', 'VBP'),
#  ('dante', 'NN'),
#  ('project', 'NN'),
#  ('digital', 'JJ'),
#  ('dante', 'NN'),
#  ('columbia', 'NN'),
#  ('university', 'NN'),
#  ('world', 'NN'),
#  ('darkest', 'NN'),
#  ('places', 'NNS'),
#  ('hell', 'VBP'),
#  ('reserved', 'VBN'),
#  ('maintain', 'VBP'),
#  ('neutrality', 'JJ'),
#  ('times', 'NNS'),
#  ('moral', 'JJ'),
#  ('crisis', 'NN'),
#  ('fact', 'NN'),
#  ('artwork', 'IN'),
#  ('literature', 'NN'),
#  ('science', 'NN'),
#  ('historical', 'JJ'),
#  ('references', 'NNS'),
#  ('novel', 'JJ'),
#  ('real', 'JJ'),
#  ('consortium', 'NN'),
#  ('private', 'JJ'),
#  ('organization', 'NN'),
#  ('offices', 'NNS'),
#  ('seven', 'CD'),
#  ('countries', 'NNS'),
#  ('name', 'RB'),
#  ('changed', 'VBD'),
#  ('considerations', 'NNS'),
#  ('security', 'NN'),
#  ('privacy', 'NN'),
#  ('inferno', 'JJ'),
#  ('underworld', 'NN'),
#  ('described', 'VBD'),
#  ('dante', 'JJ'),
#  ('alighieri', 'NN'),
#  ('epic', 'NN'),
#  ('poem', 'JJ'),
#  ('divine', 'NN'),
#  ('comedy', 'NN'),
#  ('portrays', 'NNS'),
#  ('hell', 'VBP'),
#  ('elaborately', 'RB'),
#  ('structured', 'VBN'),
#  ('realm', 'NN'),
#  ('populated', 'JJ'),
#  ('entities', 'NNS'),
#  ('known', 'VBN'),
#  ('shades', 'NNS'),
#  ('souls', 'NNS'),
#  ('trapped', 'VBD'),
#  ('life', 'NN'),
#  ('death', 'NN'),
#  ('prologue', 'NN'),
#  ('shade', 'VBD'),
#  ('dolent', 'JJ'),
#  ('city', 'NN'),
#  ('flee', 'VBP'),
#  ('eternal', 'JJ'),
#  ('woe', 'NNS'),
#  ('take', 'VB'),
#  ('flight', 'NN'),
#  ('along', 'IN'),
#  ('banks', 'NNS'),
#  ('river', 'VBP'),
#  ('arno', 'RB'),
#  ('scramble', 'JJ'),
#  ('breathless', 'NN'),
#  ('turning', 'VBG'),
#  ('left', 'VBD'),
#  ('onto', 'IN'),
#  ('via', 'IN'),
#  ('dei', 'NN'),
#  ('castellani', 'NN'),
#  ('making', 'VBG'),
#  ('way', 'NN'),
#  ('northward', 'IN'),
#  ('huddling', 'VBG'),
#  ('shadows', 'NNS'),
#  ('uffizi', 'VBP'),
#  ('still', 'RB'),
#  ('pursue', 'VB'),
#  ('footsteps', 'NNS'),
#  ('grow', 'VB'),
#  ('louder', 'RBR'),
#  ('hunt', 'NN'),
#  ('relentless', 'JJ'),
#  ('determination', 'NN'),
#  ('years', 'NNS'),
#  ('pursued', 'VBD'),
#  ('persistence', 'NN'),
#  ('kept', 'VBD'),
#  ('underground', 'RB'),
#  ('forced', 'VBN'),
#  ('live', 'JJ'),
#  ('purgatory', 'NN'),
#  ('laboring', 'VBG'),
#  ('beneath', 'JJ'),
#  ('earth', 'NN'),
#  ('like', 'IN'),
#  ('chthonic', 'JJ'),
#  ('monster', 'NN'),
#  ('shade', 'NN'),
#  ('aboveground', 'NN'),
#  ('raise', 'VB'),
#  ('eyes', 'NNS'),
#  ('north', 'JJ'),
#  ('unable', 'JJ'),
#  ('find', 'NN'),
#  ('direct', 'JJ'),
#  ('path', 'NN'),
#  ('salvation', 'NN'),
#  ('apennine', 'NN'),
#  ('mountains', 'NNS'),
#  ('blotting', 'VBG'),
#  ('first', 'JJ'),
#  ('light', 'JJ'),
#  ('dawn', 'NN'),
#  ('pass', 'NN'),
#  ('behind', 'IN'),
#  ('palazzo', 'NN'),
#  ('crenellated', 'VBN'),
#  ('tower', 'NN'),
#  ('clock', 'NN'),
#  ('snaking', 'VBG'),
#  ('vendors', 'NNS'),
#  ('piazza', 'VBP'),
#  ('di', 'JJ'),
#  ('san', 'JJ'),
#  ('firenze', 'JJ'),
#  ('hoarse', 'NN'),
#  ('voices', 'NNS'),
#  ('smelling', 'VBG'),
#  ('lampredotto', 'NN'),
#  ('roasted', 'VBD'),
#  ('olives', 'NNS'),
#  ('crossing', 'VBG'),
#  ('bargello', 'NN'),
#  ('cut', 'NN'),
#  ('west', 'JJS'),
#  ('toward', 'IN'),
#  ('spire', 'JJ'),
#  ('badia', 'NN'),
#  ('come', 'VB'),
#  ('hard', 'JJ'),
#  ('iron', 'NN'),
#  ('gate', 'NN'),
#  ('base', 'NN'),
#  ('stairs', 'JJ'),
#  ('hesitation', 'NN'),
#  ('must', 'MD'),
#  ('left', 'VB'),
#  ('behind', 'RP'),
#  ('turn', 'NN'),
#  ('handle', 'JJ'),
#  ('step', 'NN'),
#  ('passage', 'NN'),
#  ('know', 'VBP'),
#  ('return', 'NN'),
#  ('urge', 'JJ'),
#  ('leaden', 'JJ'),
#  ('legs', 'NNS'),
#  ('narrow', 'JJ'),
#  ('staircase', 'NN'),
#  ('spiraling', 'VBG'),
#  ('skyward', 'JJ'),
#  ('soft', 'JJ'),
#  ('marble', 'NN'),
#  ('treads', 'NNS'),
#  ('pitted', 'VBD'),
#  ('worn', 'JJ'),
#  ('voices', 'NNS'),
#  ('echo', 'VBP'),
#  ('beseeching', 'VBG'),
#  ('behind', 'IN'),
#  ('unyielding', 'VBG'),
#  ('closing', 'VBG'),
#  ('understand', 'NN'),
#  ('coming', 'VBG'),
#  ('done', 'VBN'),
#  ('ungrateful', 'JJ'),
#  ('land', 'NN'),
#  ('climb', 'NN'),
#  ('visions', 'NNS'),
#  ('come', 'VBP'),
#  ('hard', 'JJ'),
#  ('lustful', 'JJ'),
#  ('bodies', 'NNS'),
#  ('writhing', 'VBG'),
#  ('fiery', 'JJ'),
#  ('rain', 'NN'),
#  ('gluttonous', 'JJ'),
#  ('souls', 'NNS'),
#  ('floating', 'VBG'),
#  ('excrement', 'NN'),
#  ('treacherous', 'JJ'),
#  ('villains', 'NNS'),
#  ('frozen', 'JJ'),
#  ('satan', 'NN'),
#  ('icy', 'NN'),
#  ('grasp', 'NN'),
#  ('climb', 'VBP'),
#  ('final', 'JJ'),
#  ('stairs', 'NNS'),
#  ('arrive', 'JJ'),
#  ('top', 'JJ'),
#  ('staggering', 'NN'),
#  ('near', 'IN'),
#  ('dead', 'JJ'),
#  ('damp', 'NN'),
#  ('morning', 'NN'),
#  ('air', 'NN'),
#  ('rush', 'NN'),
#  ('wall', 'NN'),
#  ('peering', 'VBG'),
#  ('slits', 'NNS'),
#  ('far', 'RB'),
#  ('blessed', 'VBN'),
#  ('city', 'NN'),
#  ('made', 'VBN'),
#  ('sanctuary', 'JJ'),
#  ('exiled', 'JJ'),
#  ('voices', 'NNS'),
#  ('call', 'VBP'),
#  ('arriving', 'VBG'),
#  ('close', 'RB'),
#  ('behind', 'IN'),
#  ('done', 'VBN'),
#  ('madness', 'NN'),
#  ('madness', 'NN'),
#  ('breeds', 'VBZ'),
#  ('madness', 'JJ'),
#  ('love', 'IN'),
#  ('god', 'NN'),
#  ('shout', 'NN'),
#  ('tell', 'VBP'),
#  ('us', 'PRP'),
#  ('hidden', 'VBP'),
#  ('precisely', 'RB'),
#  ('love', 'IN'),
#  ('god', 'NN'),
#  ('stand', 'NN'),
#  ('cornered', 'VBD'),
#  ('back', 'RB'),
#  ('cold', 'JJ'),
#  ('stone', 'NN'),
#  ('stare', 'NN'),
#  ('deep', 'JJ'),
#  ('clear', 'JJ'),
#  ('green', 'JJ'),
#  ('eyes', 'NNS'),
#  ('expressions', 'NNS'),
#  ('darken', 'RB'),
#  ('longer', 'RBR'),
#  ('cajoling', 'VBG'),
#  ('threatening', 'VBG'),
#  ('know', 'JJ'),
#  ('methods', 'NNS'),
#  ('force', 'NN'),
#  ('tell', 'VBP'),
#  ('us', 'PRP'),
#  ('reason', 'NN'),
#  ('climbed', 'VBD'),
#  ('halfway', 'RB'),
#  ('heaven', 'VBN'),
#  ('without', 'IN'),
#  ('warning', 'VBG'),
#  ('turn', 'NN'),
#  ('reach', 'VBP'),
#  ('curling', 'VBG'),
#  ('fingers', 'NNS'),
#  ('onto', 'RB'),
#  ('high', 'JJ'),
#  ('ledge', 'NN'),
#  ('pulling', 'VBG'),
#  ('scrambling', 'VBG'),
#  ('onto', 'IN'),
#  ('knees', 'NNS'),
#  ('standing', 'VBG'),
#  ('unsteady', 'JJ'),
#  ('precipice', 'NN'),
#  ('guideme', 'NN'),
#  ('dear', 'VBP'),
#  ('virgil', 'NN'),
#  ('across', 'IN'),
#  ('void', 'JJ'),
#  ('rush', 'NN'),
#  ('forward', 'RB'),
#  ('disbelief', 'NN'),
#  ('wanting', 'VBG'),
#  ('grab', 'JJ'),
#  ('feet', 'NNS'),
#  ('fearing', 'VBG'),
#  ('upset', 'JJ'),
#  ('balance', 'NN'),
#  ('knock', 'NN'),
#  ('beg', 'NN'),
#  ('quiet', 'JJ'),
#  ('desperation', 'NN'),
#  ('turned', 'VBD'),
#  ('back', 'RB'),
#  ('know', 'JJ'),
#  ('must', 'MD'),
#  ('beneath', 'VB'),
#  ('dizzyingly', 'RB'),
#  ('far', 'RB'),
#  ('beneath', 'NN'),
#  ('red', 'JJ'),
#  ('tile', 'NN'),
#  ('roofs', 'NNS'),
#  ('spread', 'VBP'),
#  ('like', 'IN'),
#  ('sea', 'NN'),
#  ('fire', 'NN'),
#  ('countryside', 'NN'),
#  ('illuminating', 'VBG'),
#  ('fair', 'JJ'),
#  ('land', 'NN'),
#  ('upon', 'IN'),
#  ('giants', 'NNS'),
#  ('roamed', 'VBN'),
#  ('giotto', 'JJ'),
#  ('donatello', 'NN'),
#  ('brunelleschi', 'NN'),
#  ('michelangelo', 'NN'),
#  ('botticelli', 'NN'),
#  ('inch', 'NN'),
#  ('toes', 'NNS'),
#  ('edge', 'VBP'),
#  ('come', 'VBN'),
#  ('shout', 'NN'),
#  ('late', 'RB'),
#  ('willful', 'JJ'),
#  ('ignorants', 'NNS'),
#  ('see', 'VBP'),
#  ('future', 'JJ'),
#  ('grasp', 'NN'),
#  ('splendor', 'NN'),
#  ('creation', 'NN'),
#  ('necessity', 'NN'),
#  ('gladly', 'RB'),
#  ('make', 'VB'),
#  ('ultimate', 'JJ'),
#  ('sacrifice', 'NN'),
#  ('extinguish', 'JJ'),
#  ('final', 'JJ'),
#  ('hope', 'NN'),
#  ('finding', 'VBG'),
#  ('seek', 'JJ'),
#  ('never', 'RB'),
#  ('locate', 'VBP'),
#  ('time', 'NN'),
#  ('hundreds', 'NNS'),
#  ('feet', 'NNS'),
#  ('cobblestone', 'VBP'),
#  ('piazza', 'JJ'),
#  ('beckons', 'NNS'),
#  ('like', 'IN'),
#  ('tranquil', 'JJ'),
#  ('oasis', 'NN'),
#  ('long', 'JJ'),
#  ('time', 'NN'),
#  ('time', 'NN'),
#  ('one', 'CD'),
#  ('commodity', 'NN'),
#  ('even', 'RB'),
#  ('vast', 'JJ'),
#  ('fortunes', 'NNS'),
#  ('afford', 'IN'),
#  ('final', 'JJ'),
#  ('seconds', 'NNS'),
#  ('gaze', 'JJ'),
#  ('piazza', 'NN'),
#  ('behold', 'VBD'),
#  ('sight', 'JJ'),
#  ('startles', 'NNS'),
#  ('see', 'VBP'),
#  ('face', 'NN'),
#  ('gazing', 'VBG'),
#  ('shadows', 'NNS'),
#  ('eyes', 'NNS'),
#  ('mournful', 'JJ'),
#  ('yet', 'RB'),
#  ('sense', 'NN'),
#  ('veneration', 'NN'),
#  ('accomplished', 'VBD'),
#  ('understand', 'JJ'),
#  ('choice', 'NN'),
#  ('love', 'NN'),
#  ('mankind', 'NN'),
#  ('must', 'MD'),
#  ('protect', 'VB'),
#  ('masterpiece', 'NN'),
#  ('grows', 'NNS'),
#  ('even', 'RB'),
#  ('waiting', 'VBG'),
#  ('simmering', 'VBG'),
#  ('beneath', 'NN'),
#  ('bloodred', 'VBD'),
#  ('waters', 'NNS'),
#  ('lagoon', 'NN'),
#  ('reflects', 'VBZ'),
#  ('stars', 'NNS'),
#  ('lift', 'JJ'),
#  ('eyes', 'NNS'),
#  ('contemplate', 'VBP'),
#  ('horizon', 'JJ'),
#  ('high', 'JJ'),
#  ('burdened', 'VBN'),
#  ('world', 'NN'),
#  ('make', 'VBP'),
#  ('final', 'JJ'),
#  ('supplication', 'NN'),
#  ('dearest', 'JJS'),
#  ('god', 'NN'),
#  ('pray', 'NN'),
#  ('world', 'NN'),
#  ('remembers', 'NNS'),
#  ('name', 'VBP'),
#  ('monstrous', 'JJ'),
#  ('sinner', 'NN'),
#  ('glorious', 'JJ'),
#  ('savior', 'NN'),
#  ('know', 'VBP'),
#  ('truly', 'RB'),
#  ('pray', 'JJ'),
#  ('mankind', 'NN'),
#  ('understand', 'NN'),
#  ('gift', 'NN'),
#  ('leave', 'VBP'),
#  ('behind', 'IN'),
#  ('gift', 'NN'),
#  ('future', 'JJ'),
#  ('gift', 'NN'),
#  ('salvation', 'NN'),
#  ('gift', 'NN'),
#  ('inferno', 'NN'),
#  ('whisper', 'IN'),
#  ('amen', 'NNS'),
#  ('take', 'VBP'),
#  ('final', 'JJ'),
#  ('step', 'NN'),
#  ('abyss', 'RB'),
#  ('chapter', 'NN'),
#  ('memories', 'NNS'),
#  ('materialized', 'VBD'),
#  ('slowly', 'RB'),
#  ('like', 'JJ'),
#  ('bubbles', 'NNS'),
#  ('surfacing', 'VBG'),
#  ('darkness', 'NN'),
#  ('bottomless', 'NN'),
#  ('well', 'RB'),
#  ('veiled', 'JJ'),
#  ('woman', 'NN'),
#  ('robert', 'VB'),
#  ('langdon', 'JJ'),
#  ('gazed', 'VBN'),
#  ('across', 'IN'),
#  ('river', 'NN'),
#  ('whose', 'WP$'),
#  ('churning', 'VBG'),
#  ('waters', 'NNS'),
#  ('ran', 'VBD'),
#  ('red', 'JJ'),
#  ('blood', 'NN'),
#  ('far', 'RB'),
#  ('bank', 'NN'),
#  ('woman', 'NN'),
#  ('stood', 'VBD'),
#  ('facing', 'VBG'),
#  ('motionless', 'NN'),
#  ('solemn', 'JJ'),
#  ('face', 'NN'),
#  ('hidden', 'NN'),
#  ('shroud', 'JJ'),
#  ('hand', 'NN'),
#  ('gripped', 'VBD'),
#  ('blue', 'JJ'),
#  ('tainia', 'NN'),
#  ('cloth', 'NN'),
#  ('raised', 'VBD'),
#  ('honor', 'JJ'),
#  ('sea', 'NN'),
#  ('corpses', 'VBZ'),
#  ('feet', 'NNS'),
#  ('smell', 'VBP'),
#  ('death', 'NN'),
#  ('hung', 'NN'),
#  ('everywhere', 'RB'),
#  ('seek', 'JJ'),
#  ('woman', 'NN'),
#  ('whispered', 'VBD'),
#  ('ye', 'JJ'),
#  ('shall', 'MD'),
#  ('find', 'VB'),
#  ('langdon', 'JJ'),
#  ('heard', 'NN'),
#  ('words', 'NNS'),
#  ('spoken', 'VBN'),
#  ('inside', 'RB'),
#  ('head', 'NN'),
#  ('called', 'VBN'),
#  ('voice', 'NN'),
#  ('made', 'VBN'),
#  ('sound', 'JJ'),
#  ('time', 'NN'),
#  ('grows', 'VBZ'),
#  ('short', 'JJ'),
#  ('whispered', 'VBD'),
#  ('seek', 'JJ'),
#  ('find', 'NN'),
#  ('langdon', 'JJ'),
#  ('took', 'VBD'),
#  ('step', 'NN'),
#  ('toward', 'IN'),
#  ('river', 'NN'),
#  ('could', 'MD'),
#  ('see', 'VB'),
#  ('waters', 'NNS'),
#  ('bloodred', 'VBD'),
#  ('deep', 'JJ'),
#  ('traverse', 'NN'),
#  ('langdon', 'NN'),
#  ('raised', 'VBD'),
#  ('eyes', 'NNS'),
#  ('veiled', 'VBN'),
#  ('woman', 'NN'),
#  ('bodies', 'VBZ'),
#  ('feet', 'NNS'),
#  ('multiplied', 'VBD'),
#  ('hundreds', 'NNS'),
#  ('maybe', 'RB'),
#  ('thousands', 'NNS'),
#  ('still', 'RB'),
#  ('alive', 'JJ'),
#  ('writhing', 'VBG'),
#  ('agony', 'NN'),
#  ('dying', 'VBG'),
#  ('unthinkable', 'JJ'),
#  ('deaths', 'NNS'),
#  ('consumed', 'VBN'),
#  ('fire', 'NN'),
#  ('buried', 'VBN'),
#  ...]

# %%
tag_distribution = nltk.FreqDist(tag for word, tag in pos_tags)
tag_distribution
# Out:
# FreqDist({'NN': 26955, 'JJ': 14245, 'VBD': 8278, 'RB': 6032, 'NNS': 5901, 'VBG': 4644, 'VBN': 3019, 'VBP': 2392, 'IN': 1930, 'VB': 1545, ...})

# %%
print(tag_distribution.most_common())
# Out:
# [('NN', 26955), ('JJ', 14245), ('VBD', 8278), ('RB', 6032), ('NNS', 5901), ('VBG', 4644), ('VBN', 3019), ('VBP', 2392), ('IN', 1930), ('VB', 1545), ('MD', 858), ('CD', 824), ('VBZ', 620), ('JJR', 270), ('RBR', 253), ('JJS', 190), ('DT', 166), ('RP', 130), ('FW', 127), ('PRP', 118), ('NNP', 46), ('WP$', 40), ('CC', 35), ('WDT', 33), ('UH', 11), ('RBS', 8), ('WP', 7), ('WRB', 4), ('PRP$', 1), ('POS', 1)]

# %% [markdown]
# # Extracting the largest chapter and Tokenization

# %% [markdown]
# Extract the largest chapter, Chapter C
# The Largest Chapter in our book is Chapter 100 with 2831 words and
# start index = 837000
# end index = 854415

# %%
start_index_c = 837000
end_index_c = 854415
chapter_c_text = cleaned_text[start_index_c:end_index_c]

# %%
chapter_c_tokens = word_tokenize(chapter_c_text.lower())

# %% [markdown]
# # Bigram of the largest chapter

# %%
bi_grams_c = list(bigrams(chapter_c_tokens))
bi_gram_freq_c = FreqDist(bi_grams_c)
bi_gram_probabilities_c = ConditionalFreqDist(bi_grams_c)

# %%
bi_grams_c
# Out:
# [('gravel', 'path'),
#  ('path', ','),
#  (',', 'farther'),
#  ('farther', 'away'),
#  ('away', 'from'),
#  ('from', 'the'),
#  ('the', 'water'),
#  ('water', 'and'),
#  ('and', 'the'),
#  ('the', 'crowds'),
#  ('crowds', '.'),
#  ('.', 'although'),
#  ('although', 'sienna'),
#  ('sienna', '’'),
#  ('’', 's'),
#  ('s', 'tears'),
#  ('tears', 'had'),
#  ('had', 'stopped'),
#  ('stopped', ','),
#  (',', 'langdon'),
#  ('langdon', 'sensed'),
#  ('sensed', 'a'),
#  ('a', 'torrent'),
#  ('torrent', 'of'),
#  ('of', 'emotion'),
#  ('emotion', 'building'),
#  ('building', 'up'),
#  ('up', 'within'),
#  ('within', 'her'),
#  ('her', '.'),
#  ('.', 'he'),
#  ('he', 'could'),
#  ('could', 'hear'),
#  ('hear', 'sirens'),
#  ('sirens', 'wailing'),
#  ('wailing', 'in'),
#  ('in', 'the'),
#  ('the', 'distance'),
#  ('distance', ','),
#  (',', 'but'),
#  ('but', 'sienna'),
#  ('sienna', 'appeared'),
#  ('appeared', 'not'),
#  ('not', 'to'),
#  ('to', 'notice'),
#  ('notice', '.'),
#  ('.', 'she'),
#  ('she', 'was'),
#  ('was', 'staring'),
#  ('staring', 'blankly'),
#  ('blankly', 'at'),
#  ('at', 'the'),
#  ('the', 'ground'),
#  ('ground', ','),
#  (',', 'seemingly'),
#  ('seemingly', 'hypnotized'),
#  ('hypnotized', 'by'),
#  ('by', 'the'),
#  ('the', 'rhythmic'),
#  ('rhythmic', 'crunch'),
#  ('crunch', 'of'),
#  ('of', 'the'),
#  ('the', 'gravel'),
#  ('gravel', 'beneath'),
#  ('beneath', 'their'),
#  ('their', 'feet'),
#  ('feet', '.'),
#  ('.', 'they'),
#  ('they', 'entered'),
#  ('entered', 'a'),
#  ('a', 'small'),
#  ('small', 'park'),
#  ('park', ','),
#  (',', 'and'),
#  ('and', 'sienna'),
#  ('sienna', 'guided'),
#  ('guided', 'him'),
#  ('him', 'into'),
#  ('into', 'a'),
#  ('a', 'dense'),
#  ('dense', 'grove'),
#  ('grove', 'of'),
#  ('of', 'trees'),
#  ('trees', ','),
#  (',', 'where'),
#  ('where', 'they'),
#  ('they', 'were'),
#  ('were', 'hidden'),
#  ('hidden', 'away'),
#  ('away', 'from'),
#  ('from', 'the'),
#  ('the', 'world'),
#  ('world', '.'),
#  ('.', 'here'),
#  ('here', 'they'),
#  ('they', 'sat'),
#  ('sat', 'on'),
#  ('on', 'a'),
#  ('a', 'bench'),
#  ('bench', 'that'),
#  ('that', 'overlooked'),
#  ('overlooked', 'the'),
#  ('the', 'water'),
#  ('water', '.'),
#  ('.', 'on'),
#  ('on', 'the'),
#  ('the', 'far'),
#  ('far', 'shore'),
#  ('shore', ','),
#  (',', 'the'),
#  ('the', 'ancient'),
#  ('ancient', 'galata'),
#  ('galata', 'tower'),
#  ('tower', 'glistened'),
#  ('glistened', 'above'),
#  ('above', 'the'),
#  ('the', 'quiet'),
#  ('quiet', 'residences'),
#  ('residences', 'that'),
#  ('that', 'dotted'),
#  ('dotted', 'the'),
#  ('the', 'hillside'),
#  ('hillside', '.'),
#  ('.', 'the'),
#  ('the', 'world'),
#  ('world', 'looked'),
#  ('looked', 'strangely'),
#  ('strangely', 'peaceful'),
#  ('peaceful', 'from'),
#  ('from', 'here'),
#  ('here', ','),
#  (',', 'a'),
#  ('a', 'far'),
#  ('far', 'cry'),
#  ('cry', ','),
#  (',', 'langdon'),
#  ('langdon', 'imagined'),
#  ('imagined', ','),
#  (',', 'from'),
#  ('from', 'what'),
#  ('what', 'was'),
#  ('was', 'probably'),
#  ('probably', 'transpiring'),
#  ('transpiring', 'at'),
#  ('at', 'the'),
#  ('the', 'cistern'),
#  ('cistern', '.'),
#  ('.', 'by'),
#  ('by', 'now'),
#  ('now', ','),
#  (',', 'he'),
#  ('he', 'suspected'),
#  ('suspected', ','),
#  (',', 'sinskey'),
#  ('sinskey', 'and'),
#  ('and', 'the'),
#  ('the', 'srs'),
#  ('srs', 'team'),
#  ('team', 'had'),
#  ('had', 'realized'),
#  ('realized', 'that'),
#  ('that', 'they'),
#  ('they', 'had'),
#  ('had', 'arrived'),
#  ('arrived', 'too'),
#  ('too', 'late'),
#  ('late', 'to'),
#  ('to', 'stop'),
#  ('stop', 'the'),
#  ('the', 'plague'),
#  ('plague', '.'),
#  ('.', 'beside'),
#  ('beside', 'him'),
#  ('him', ','),
#  (',', 'sienna'),
#  ('sienna', 'stared'),
#  ('stared', 'out'),
#  ('out', 'across'),
#  ('across', 'the'),
#  ('the', 'sea'),
#  ('sea', '.'),
#  ('.', '“'),
#  ('“', 'i'),
#  ('i', 'don'),
#  ('don', '’'),
#  ('’', 't'),
#  ('t', 'have'),
#  ('have', 'much'),
#  ('much', 'time'),
#  ('time', ','),
#  (',', 'robert'),
#  ('robert', ','),
#  (',', '”'),
#  ('”', 'she'),
#  ('she', 'said'),
#  ('said', '.'),
#  ('.', '“'),
#  ('“', 'the'),
#  ('the', 'authorities'),
#  ('authorities', 'will'),
#  ('will', 'eventually'),
#  ('eventually', 'figure'),
#  ('figure', 'out'),
#  ('out', 'where'),
#  ('where', 'i'),
#  ('i', 'went'),
#  ('went', '.'),
#  ('.', 'but'),
#  ('but', 'before'),
#  ('before', 'they'),
#  ('they', 'do'),
#  ('do', ','),
#  (',', 'i'),
#  ('i', 'need'),
#  ('need', 'you'),
#  ('you', 'to'),
#  ('to', 'hear'),
#  ('hear', 'the'),
#  ('the', 'truth'),
#  ('truth', '…'),
#  ('…', 'all'),
#  ('all', 'of'),
#  ('of', 'it.'),
#  ('it.', '”'),
#  ('”', 'langdon'),
#  ('langdon', 'gave'),
#  ('gave', 'her'),
#  ('her', 'a'),
#  ('a', 'silent'),
#  ('silent', 'nod'),
#  ('nod', '.'),
#  ('.', 'sienna'),
#  ('sienna', 'wiped'),
#  ('wiped', 'her'),
#  ('her', 'eyes'),
#  ('eyes', 'and'),
#  ('and', 'shifted'),
#  ('shifted', 'on'),
#  ('on', 'the'),
#  ('the', 'bench'),
#  ('bench', 'to'),
#  ('to', 'face'),
#  ('face', 'him'),
#  ('him', 'fully'),
#  ('fully', '.'),
#  ('.', '“'),
#  ('“', 'bertrand'),
#  ('bertrand', 'zobrist'),
#  ('zobrist', '…'),
#  ('…', '”'),
#  ('”', 'she'),
#  ('she', 'began'),
#  ('began', '.'),
#  ('.', '“'),
#  ('“', 'he'),
#  ('he', 'was'),
#  ('was', 'my'),
#  ('my', 'first'),
#  ('first', 'love'),
#  ('love', '.'),
#  ('.', 'he'),
#  ('he', 'became'),
#  ('became', 'my'),
#  ('my', 'mentor.'),
#  ('mentor.', '”'),
#  ('”', '“'),
#  ('“', 'i'),
#  ('i', '’'),
#  ('’', 've'),
#  ('ve', 'already'),
#  ('already', 'been'),
#  ('been', 'told'),
#  ('told', ','),
#  (',', 'sienna'),
#  ('sienna', ','),
#  (',', '”'),
#  ('”', 'langdon'),
#  ('langdon', 'said'),
#  ('said', '.'),
#  ('.', 'she'),
#  ('she', 'gave'),
#  ('gave', 'him'),
#  ('him', 'a'),
#  ('a', 'startled'),
#  ('startled', 'look'),
#  ('look', 'but'),
#  ('but', 'continued'),
#  ('continued', 'speaking'),
#  ('speaking', ','),
#  (',', 'as'),
#  ('as', 'if'),
#  ('if', 'afraid'),
#  ('afraid', 'to'),
#  ('to', 'lose'),
#  ('lose', 'her'),
#  ('her', 'momentum'),
#  ('momentum', '.'),
#  ('.', '“'),
#  ('“', 'i'),
#  ('i', 'met'),
#  ('met', 'him'),
#  ('him', 'at'),
#  ('at', 'an'),
#  ('an', 'impressionable'),
#  ('impressionable', 'age'),
#  ('age', ','),
#  (',', 'and'),
#  ('and', 'his'),
#  ('his', 'ideas'),
#  ('ideas', 'and'),
#  ('and', 'intellect'),
#  ('intellect', 'bewitched'),
#  ('bewitched', 'me'),
#  ('me', '.'),
#  ('.', 'bertrand'),
#  ('bertrand', 'believed'),
#  ('believed', ','),
#  (',', 'as'),
#  ('as', 'i'),
#  ('i', 'do'),
#  ('do', ','),
#  (',', 'that'),
#  ('that', 'our'),
#  ('our', 'species'),
#  ('species', 'is'),
#  ('is', 'on'),
#  ('on', 'the'),
#  ('the', 'brink'),
#  ('brink', 'of'),
#  ('of', 'collapse'),
#  ('collapse', '…'),
#  ('…', 'that'),
#  ('that', 'we'),
#  ('we', '’'),
#  ('’', 're'),
#  ('re', 'facing'),
#  ('facing', 'a'),
#  ('a', 'horrifying'),
#  ('horrifying', 'end'),
#  ('end', ','),
#  (',', 'which'),
#  ('which', 'is'),
#  ('is', 'racing'),
#  ('racing', 'toward'),
#  ('toward', 'us'),
#  ('us', 'so'),
#  ('so', 'much'),
#  ('much', 'faster'),
#  ('faster', 'than'),
#  ('than', 'anyone'),
#  ('anyone', 'dares'),
#  ('dares', 'accept.'),
#  ('accept.', '”'),
#  ('”', 'langdon'),
#  ('langdon', 'made'),
#  ('made', 'no'),
#  ('no', 'reply'),
#  ('reply', '.'),
#  ('.', '“'),
#  ('“', 'my'),
#  ('my', 'entire'),
#  ('entire', 'childhood'),
#  ('childhood', ','),
#  (',', '”'),
#  ('”', 'sienna'),
#  ('sienna', 'said'),
#  ('said', ','),
#  (',', '“'),
#  ('“', 'i'),
#  ('i', 'wanted'),
#  ('wanted', 'to'),
#  ('to', 'save'),
#  ('save', 'the'),
#  ('the', 'world'),
#  ('world', '.'),
#  ('.', 'and'),
#  ('and', 'all'),
#  ('all', 'i'),
#  ('i', 'was'),
#  ('was', 'ever'),
#  ('ever', 'told'),
#  ('told', 'was'),
#  ('was', ':'),
#  (':', '‘'),
#  ('‘', 'you'),
#  ('you', 'can'),
#  ('can', '’'),
#  ('’', 't'),
#  ('t', 'save'),
#  ('save', 'the'),
#  ('the', 'world'),
#  ('world', ','),
#  (',', 'so'),
#  ('so', 'don'),
#  ('don', '’'),
#  ('’', 't'),
#  ('t', 'sacrifice'),
#  ('sacrifice', 'your'),
#  ('your', 'happiness'),
#  ('happiness', 'trying.'),
#  ('trying.', '’'),
#  ('’', '”'),
#  ('”', 'she'),
#  ('she', 'paused'),
#  ('paused', ','),
#  (',', 'her'),
#  ('her', 'face'),
#  ('face', 'taut'),
#  ('taut', ','),
#  (',', 'holding'),
#  ('holding', 'back'),
#  ('back', 'tears'),
#  ('tears', '.'),
#  ('.', '“'),
#  ('“', 'then'),
#  ('then', 'i'),
#  ('i', 'met'),
#  ('met', 'bertrand—a'),
#  ('bertrand—a', 'beautiful'),
#  ('beautiful', ','),
#  (',', 'brilliant'),
#  ('brilliant', 'man'),
#  ('man', 'who'),
#  ('who', 'told'),
#  ('told', 'me'),
#  ('me', 'not'),
#  ('not', 'only'),
#  ('only', 'that'),
#  ('that', 'saving'),
#  ('saving', 'the'),
#  ('the', 'world'),
#  ('world', 'was'),
#  ('was', 'possible'),
#  ('possible', '…'),
#  ('…', 'but'),
#  ('but', 'that'),
#  ('that', 'doing'),
#  ('doing', 'so'),
#  ('so', 'was'),
#  ('was', 'a'),
#  ('a', 'moral'),
#  ('moral', 'imperative'),
#  ('imperative', '.'),
#  ('.', 'he'),
#  ('he', 'introduced'),
#  ('introduced', 'me'),
#  ('me', 'to'),
#  ('to', 'an'),
#  ('an', 'entire'),
#  ('entire', 'circle'),
#  ('circle', 'of'),
#  ('of', 'like-minded'),
#  ('like-minded', 'individuals—people'),
#  ('individuals—people', 'of'),
#  ('of', 'staggering'),
#  ('staggering', 'abilities'),
#  ('abilities', 'and'),
#  ('and', 'intellect'),
#  ('intellect', '…'),
#  ('…', 'people'),
#  ('people', 'who'),
#  ('who', 'really'),
#  ('really', 'could'),
#  ('could', 'change'),
#  ('change', 'the'),
#  ('the', 'future'),
#  ('future', '.'),
#  ('.', 'for'),
#  ('for', 'the'),
#  ('the', 'first'),
#  ('first', 'time'),
#  ('time', 'in'),
#  ('in', 'my'),
#  ('my', 'life'),
#  ('life', ','),
#  (',', 'i'),
#  ('i', 'no'),
#  ('no', 'longer'),
#  ('longer', 'felt'),
#  ('felt', 'all'),
#  ('all', 'alone'),
#  ('alone', ','),
#  (',', 'robert.'),
#  ('robert.', '”'),
#  ('”', 'langdon'),
#  ('langdon', 'offered'),
#  ('offered', 'a'),
#  ('a', 'soft'),
#  ('soft', 'smile'),
#  ('smile', ','),
#  (',', 'sensing'),
#  ('sensing', 'the'),
#  ('the', 'pain'),
#  ('pain', 'in'),
#  ('in', 'her'),
#  ('her', 'words'),
#  ('words', '.'),
#  ('.', '“'),
#  ('“', 'i'),
#  ('i', '’'),
#  ('’', 've'),
#  ('ve', 'endured'),
#  ('endured', 'some'),
#  ('some', 'terrible'),
#  ('terrible', 'things'),
#  ('things', 'in'),
#  ('in', 'my'),
#  ('my', 'life'),
#  ('life', ','),
#  (',', '”'),
#  ('”', 'sienna'),
#  ('sienna', 'continued'),
#  ('continued', ','),
#  (',', 'her'),
#  ('her', 'voice'),
#  ('voice', 'increasingly'),
#  ('increasingly', 'unsteady'),
#  ('unsteady', '.'),
#  ('.', '“'),
#  ('“', 'things'),
#  ('things', 'i'),
#  ('i', '’'),
#  ('’', 've'),
#  ('ve', 'had'),
#  ('had', 'trouble'),
#  ('trouble', 'moving'),
#  ('moving', 'past'),
#  ('past', '…'),
#  ('…', '”'),
#  ('”', 'she'),
#  ('she', 'broke'),
#  ('broke', 'his'),
#  ('his', 'gaze'),
#  ('gaze', 'and'),
#  ('and', 'ran'),
#  ('ran', 'an'),
#  ('an', 'anxiouspalm'),
#  ('anxiouspalm', 'across'),
#  ('across', 'her'),
#  ('her', 'bald'),
#  ('bald', 'scalp'),
#  ('scalp', 'before'),
#  ('before', 'collecting'),
#  ('collecting', 'herself'),
#  ('herself', 'and'),
#  ('and', 'turning'),
#  ('turning', 'back'),
#  ('back', 'to'),
#  ('to', 'him'),
#  ('him', '.'),
#  ('.', '“'),
#  ('“', 'and'),
#  ('and', 'maybe'),
#  ('maybe', 'that'),
#  ('that', '’'),
#  ('’', 's'),
#  ('s', 'why'),
#  ('why', 'the'),
#  ('the', 'only'),
#  ('only', 'thing'),
#  ('thing', 'that'),
#  ('that', 'keeps'),
#  ('keeps', 'me'),
#  ('me', 'going'),
#  ('going', 'is'),
#  ('is', 'my'),
#  ('my', 'belief'),
#  ('belief', 'that'),
#  ('that', 'we'),
#  ('we', 'are'),
#  ('are', 'capable'),
#  ('capable', 'of'),
#  ('of', 'being'),
#  ('being', 'better'),
#  ('better', 'than'),
#  ('than', 'we'),
#  ('we', 'are'),
#  ('are', '…'),
#  ('…', 'capable'),
#  ('capable', 'of'),
#  ('of', 'taking'),
#  ('taking', 'action'),
#  ('action', 'to'),
#  ('to', 'avoid'),
#  ('avoid', 'a'),
#  ('a', 'catastrophic'),
#  ('catastrophic', 'future.'),
#  ('future.', '”'),
#  ('”', '“'),
#  ('“', 'and'),
#  ('and', 'bertrand'),
#  ('bertrand', 'believed'),
#  ('believed', 'that'),
#  ('that', ','),
#  (',', 'too'),
#  ('too', '?'),
#  ('?', '”'),
#  ('”', 'langdon'),
#  ('langdon', 'asked'),
#  ('asked', '.'),
#  ('.', '“'),
#  ('“', 'absolutely'),
#  ('absolutely', '.'),
#  ('.', 'bertrand'),
#  ('bertrand', 'had'),
#  ('had', 'boundless'),
#  ('boundless', 'hope'),
#  ('hope', 'for'),
#  ('for', 'humankind'),
#  ('humankind', '.'),
#  ('.', 'he'),
#  ('he', 'was'),
#  ('was', 'a'),
#  ('a', 'transhumanist'),
#  ('transhumanist', 'who'),
#  ('who', 'believed'),
#  ('believed', 'we'),
#  ('we', 'are'),
#  ('are', 'living'),
#  ('living', 'on'),
#  ('on', 'the'),
#  ('the', 'threshold'),
#  ('threshold', 'of'),
#  ('of', 'a'),
#  ('a', 'glittering'),
#  ('glittering', '‘'),
#  ('‘', 'posthuman'),
#  ('posthuman', '’'),
#  ('’', 'age—an'),
#  ('age—an', 'era'),
#  ('era', 'of'),
#  ('of', 'true'),
#  ('true', 'transformation'),
#  ('transformation', '.'),
#  ('.', 'he'),
#  ('he', 'had'),
#  ('had', 'the'),
#  ('the', 'mind'),
#  ('mind', 'of'),
#  ('of', 'a'),
#  ('a', 'futurist'),
#  ('futurist', ','),
#  (',', 'eyes'),
#  ('eyes', 'that'),
#  ('that', 'could'),
#  ('could', 'see'),
#  ('see', 'down'),
#  ('down', 'the'),
#  ('the', 'road'),
#  ('road', 'in'),
#  ('in', 'ways'),
#  ('ways', 'few'),
#  ('few', 'others'),
#  ('others', 'could'),
#  ('could', 'even'),
#  ('even', 'imagine'),
#  ('imagine', '.'),
#  ('.', 'he'),
#  ('he', 'understood'),
#  ('understood', 'the'),
#  ('the', 'astonishing'),
#  ('astonishing', 'powers'),
#  ('powers', 'of'),
#  ('of', 'technology'),
#  ('technology', 'and'),
#  ('and', 'believed'),
#  ('believed', 'that'),
#  ('that', 'in'),
#  ('in', 'the'),
#  ('the', 'span'),
#  ('span', 'of'),
#  ('of', 'several'),
#  ('several', 'generations'),
#  ('generations', ','),
#  (',', 'our'),
#  ('our', 'species'),
#  ('species', 'would'),
#  ('would', 'become'),
#  ('become', 'a'),
#  ('a', 'different'),
#  ('different', 'animal'),
#  ('animal', 'entirely—genetically'),
#  ('entirely—genetically', 'enhanced'),
#  ('enhanced', 'to'),
#  ('to', 'be'),
#  ('be', 'healthier'),
#  ('healthier', ','),
#  (',', 'smarter'),
#  ('smarter', ','),
#  (',', 'stronger'),
#  ('stronger', ','),
#  (',', 'even'),
#  ('even', 'more'),
#  ('more', 'compassionate.'),
#  ('compassionate.', '”'),
#  ('”', 'she'),
#  ('she', 'paused'),
#  ('paused', '.'),
#  ('.', '“'),
#  ('“', 'except'),
#  ('except', 'for'),
#  ('for', 'one'),
#  ('one', 'problem'),
#  ('problem', '.'),
#  ('.', 'he'),
#  ('he', 'didn'),
#  ('didn', '’'),
#  ('’', 't'),
#  ('t', 'think'),
#  ('think', 'we'),
#  ('we', '’'),
#  ('’', 'd'),
#  ('d', 'live'),
#  ('live', 'long'),
#  ('long', 'enough'),
#  ('enough', 'as'),
#  ('as', 'a'),
#  ('a', 'species'),
#  ('species', 'to'),
#  ('to', 'realize'),
#  ('realize', 'that'),
#  ('that', 'possibility.'),
#  ('possibility.', '”'),
#  ('”', '“'),
#  ('“', 'due'),
#  ('due', 'to'),
#  ('to', 'overpopulation'),
#  ('overpopulation', '…'),
#  ('…', '”'),
#  ('”', 'langdon'),
#  ('langdon', 'said'),
#  ('said', '.'),
#  ('.', 'she'),
#  ('she', 'nodded'),
#  ('nodded', '.'),
#  ('.', '“'),
#  ('“', 'the'),
#  ('the', 'malthusian'),
#  ('malthusian', 'catastrophe'),
#  ('catastrophe', '.'),
#  ('.', 'bertrand'),
#  ('bertrand', 'used'),
#  ('used', 'to'),
#  ('to', 'tell'),
#  ('tell', 'me'),
#  ('me', 'he'),
#  ('he', 'felt'),
#  ('felt', 'like'),
#  ('like', 'st.'),
#  ('st.', 'george'),
#  ('george', 'trying'),
#  ('trying', 'to'),
#  ('to', 'slay'),
#  ('slay', 'the'),
#  ('the', 'chthonic'),
#  ('chthonic', 'monster.'),
#  ('monster.', '”'),
#  ('”', 'langdon'),
#  ('langdon', 'didn'),
#  ('didn', '’'),
#  ('’', 't'),
#  ('t', 'follow'),
#  ('follow', 'her'),
#  ('her', 'meaning'),
#  ('meaning', '.'),
#  ('.', '“'),
#  ('“', 'medusa'),
#  ('medusa', '?'),
#  ('?', '”'),
#  ('”', '“'),
#  ('“', 'metaphorically'),
#  ('metaphorically', ','),
#  (',', 'yes'),
#  ('yes', '.'),
#  ('.', 'medusa'),
#  ('medusa', 'and'),
#  ('and', 'the'),
#  ('the', 'entire'),
#  ('entire', 'class'),
#  ('class', 'of'),
#  ('of', 'chthonic'),
#  ('chthonic', 'deities'),
#  ('deities', 'live'),
#  ('live', 'underground'),
#  ('underground', 'because'),
#  ('because', 'they'),
#  ('they', '’'),
#  ('’', 're'),
#  ('re', 'associated'),
#  ('associated', 'directly'),
#  ('directly', 'with'),
#  ('with', 'mother'),
#  ('mother', 'earth'),
#  ('earth', '.'),
#  ('.', 'in'),
#  ('in', 'allegory'),
#  ('allegory', ','),
#  (',', 'chthonics'),
#  ('chthonics', 'are'),
#  ('are', 'always'),
#  ('always', 'symbols'),
#  ('symbols', 'of—'),
#  ('of—', '”'),
#  ('”', '“'),
#  ('“', 'fertility'),
#  ('fertility', ','),
#  (',', '”'),
#  ('”', 'langdon'),
#  ('langdon', 'said'),
#  ('said', ','),
#  (',', 'startled'),
#  ('startled', 'that'),
#  ('that', 'the'),
#  ('the', 'parallel'),
#  ('parallel', 'had'),
#  ('had', 'not'),
#  ('not', 'occurred'),
#  ('occurred', 'to'),
#  ('to', 'him'),
#  ('him', 'earlier'),
#  ('earlier', '.'),
#  ('.', 'fruitfulness'),
#  ('fruitfulness', '.'),
#  ('.', 'population'),
#  ('population', '.'),
#  ('.', '“'),
#  ('“', 'yes'),
#  ('yes', ','),
#  (',', 'fertility'),
#  ('fertility', ','),
#  (',', '”'),
#  ('”', 'sienna'),
#  ('sienna', 'replied'),
#  ('replied', '.'),
#  ('.', '“'),
#  ('“', 'bertrand'),
#  ('bertrand', 'used'),
#  ('used', 'the'),
#  ('the', 'term'),
#  ('term', '‘'),
#  ('‘', 'chthonic'),
#  ('chthonic', 'monster'),
#  ('monster', '’'),
#  ('’', 'to'),
#  ('to', 'represent'),
#  ('represent', 'the'),
#  ('the', 'ominous'),
#  ('ominous', 'threat'),
#  ('threat', 'of'),
#  ('of', 'our'),
#  ('our', 'own'),
#  ('own', 'fecundity'),
#  ('fecundity', '.'),
#  ('.', 'he'),
#  ('he', 'described'),
#  ('described', 'our'),
#  ('our', 'overproduction'),
#  ('overproduction', 'of'),
#  ('of', 'offspring'),
#  ('offspring', 'as'),
#  ('as', 'a'),
#  ('a', 'monster'),
#  ('monster', 'looming'),
#  ('looming', 'on'),
#  ('on', 'the'),
#  ('the', 'horizon'),
#  ('horizon', '…'),
#  ('…', 'a'),
#  ('a', 'monster'),
#  ('monster', 'we'),
#  ('we', 'needed'),
#  ('needed', 'to'),
#  ('to', 'contain'),
#  ('contain', 'immediately'),
#  ('immediately', ','),
#  (',', 'before'),
#  ('before', 'it'),
#  ('it', 'consumed'),
#  ('consumed', 'us'),
#  ('us', 'all.'),
#  ('all.', '”'),
#  ('”', 'our'),
#  ('our', 'own'),
#  ('own', 'virility'),
#  ('virility', 'stalks'),
#  ('stalks', 'us'),
#  ('us', ','),
#  (',', 'langdon'),
#  ('langdon', 'realized'),
#  ('realized', '.'),
#  ('.', 'the'),
#  ('the', 'chthonic'),
#  ('chthonic', 'monster'),
#  ('monster', '.'),
#  ('.', '“'),
#  ('“', 'and'),
#  ('and', 'bertrand'),
#  ('bertrand', 'battled'),
#  ('battled', 'this'),
#  ('this', 'monster'),
#  ('monster', '…'),
#  ('…', 'how'),
#  ('how', '?'),
#  ('?', '”'),
#  ('”', '“'),
#  ('“', 'please'),
#  ('please', 'understand'),
#  ('understand', ','),
#  (',', '”'),
#  ('”', 'she'),
#  ('she', 'said'),
#  ('said', 'defensively'),
#  ('defensively', ','),
#  (',', '“'),
#  ('“', 'these'),
#  ('these', 'are'),
#  ('are', 'not'),
#  ('not', 'easy'),
#  ('easy', 'problems'),
#  ('problems', 'to'),
#  ('to', 'solve'),
#  ('solve', '.'),
#  ('.', 'triage'),
#  ('triage', 'is'),
#  ('is', 'always'),
#  ('always', 'a'),
#  ('a', 'messy'),
#  ('messy', 'process'),
#  ('process', '.'),
#  ('.', 'a'),
#  ('a', 'man'),
#  ('man', 'who'),
#  ('who', 'severs'),
#  ('severs', 'the'),
#  ('the', 'leg'),
#  ('leg', 'of'),
#  ('of', 'a'),
#  ('a', 'three-year-old'),
#  ('three-year-old', 'child'),
#  ('child', 'is'),
#  ('is', 'a'),
#  ('a', 'horrific'),
#  ('horrific', 'criminal'),
#  ('criminal', '…'),
#  ('…', 'until'),
#  ('until', 'that'),
#  ('that', 'man'),
#  ('man', 'is'),
#  ('is', 'a'),
#  ('a', 'doctor'),
#  ('doctor', 'who'),
#  ('who', 'saves'),
#  ('saves', 'the'),
#  ('the', 'child'),
#  ('child', 'from'),
#  ('from', 'gangrene'),
#  ('gangrene', '.'),
#  ('.', 'sometimes'),
#  ('sometimes', 'the'),
#  ('the', 'only'),
#  ('only', 'choice'),
#  ('choice', 'is'),
#  ('is', 'the'),
#  ('the', 'lesser'),
#  ('lesser', 'of'),
#  ('of', 'two'),
#  ('two', 'evils.'),
#  ('evils.', '”'),
#  ('”', 'she'),
#  ('she', 'began'),
#  ('began', 'tearing'),
#  ('tearing', 'up'),
#  ('up', 'again'),
#  ('again', '.'),
#  ('.', '“'),
#  ('“', 'i'),
#  ('i', 'believe'),
#  ('believe', 'bertrand'),
#  ('bertrand', 'had'),
#  ('had', 'a'),
#  ('a', 'noble'),
#  ('noble', 'goal'),
#  ('goal', '…'),
#  ('…', 'but'),
#  ('but', 'his'),
#  ('his', 'methods'),
#  ('methods', '…'),
#  ('…', '”'),
#  ('”', 'she'),
#  ('she', 'looked'),
#  ('looked', 'away'),
#  ('away', ','),
#  (',', 'on'),
#  ('on', 'the'),
#  ('the', 'verge'),
#  ('verge', 'of'),
#  ('of', 'breaking'),
#  ('breaking', 'down'),
#  ('down', '.'),
#  ('.', '“'),
#  ...]

# %%
bi_gram_freq_c
# Out:
# FreqDist({('.', '“'): 59, ('’', 's'): 24, ('”', '“'): 24, (',', '”'): 23, ('”', 'langdon'): 22, ('’', 't'): 20, ('”', 'she'): 18, ('.', 'he'): 15, ('of', 'the'): 15, ('“', 'i'): 15, ...})

# %% [markdown]
# # Chosing other chapter and Tokenization

# %% [markdown]
# Extracting any random chapter
# In our case we are extracting Chapter 50 with 853 words
# starting index = 391725
# end index = 396594

# %%
start_index_other = 391725
end_index_other = 396594

chapter_other_text = cleaned_text[start_index_other:end_index_other]

# %%
chapter_other_tokens = word_tokenize(chapter_other_text.lower())

# %% [markdown]
# # Shannon Game

# %%
blanks = []
for i in range(len(chapter_other_tokens) - 1):
    current_word = chapter_other_tokens[i]
    next_word = chapter_other_tokens[i + 1]
    if current_word in stop_words:
        blanks.append(current_word)
    elif (current_word, next_word) in bi_gram_probabilities_c:
        if random.random() < bi_gram_probabilities_c[current_word].freq(next_word):
            blanks.append(current_word)
        else:
            blanks.append("___")
    else:
        blanks.append(current_word)

# %% [markdown]
# # Output

# %%
# Fill in the last word of the chapter
blanks.append(chapter_other_tokens[-1])

# Print the filled-in chapter
filled_chapter = ' '.join(blanks)
print(filled_chapter)
# Out:
# et passages tour . the duke of athens stairway . the sound of running footsteps and shouting seemed to be coming from all directions now , and langdon knew their time was short . he pulled aside the curtain , and he and sienna slipped through onto a small landing . without a word , they began to descend the stone staircase . the passage had been designed as a series of frighteningly narrow switchback stairs . the deeper they went , the tighter it seemed to get . just as langdon felt as if the walls were moving in to crush him , thankfully , they could go no farther . ground level . the space at the bottom of the stairs was a tiny stone chamber , and although its exit had to be one of the smallest doors on earth , it was a welcome sight . only about four feet high , the door was made of heavy wood with iron rivets and a heavy interior bolt to keep people out . “ i can hear street sounds beyond the door , ” sienna whispered , still looking shaken . “ what ’ s on the other side ? ” “ the via della ninna , ” langdon replied , picturing the crowded pedestrian walkway . “ but there may be police. ” “ they won ’ t recognize us . they ’ ll be looking for a blond girl and a dark-haired man. ” langdon eyed her strangely . “ which is precisely what we are … ” sienna shook her head , a melancholy resolve crossing her face . “ i didn ’ t want you to see me like this , robert , but unfortunately it ’ s what i look like at the moment. ” abruptly , sienna reached up and grabbed a handful of her blond hair . then she yanked down , and all of her hair slid off in a single motion.langdon recoiled , startled both by the fact that sienna wore a wig and by her altered appearance without it . sienna brooks was in fact totally bald , her bare scalp smooth and pale , like a cancer patient undergoing chemotherapy . on top of it all , she ’ s ill ? “ i know , ” she said . “ long story . now bend down. ” she held up the wig , clearly intending to put it on langdon ’ s head . is she serious ? langdon halfheartedly bent over , and sienna wedged the blond hair onto his head . the wig barely fit , but she arranged it as best as she could . then she stepped back and assessed him . not quite satisfied , she reached up , loosened his tie , and slipped the loop up onto his forehead , retightening it like a bandanna and securing the ill- fitting wig to his head . sienna now set to work on herself , rolling up her pant legs and pushing her socks down around her ankles . when she stood up , she had a sneer on her lips . the lovely sienna brooks was now a punk-rock skinhead . the former shakespearean actress ’ s transformation was startling . “ remember , ” she said , “ ninety percent of personal recognition is body language , so when you move , move like an aging rocker. ” aging , i can do , langdon thought . rocker , i ’ m not so sure . before langdon could argue the point , sienna had unbolted the tiny door and swung it open . she ducked low and exited onto the crowded cobblestone street . langdon followed , nearly on all fours as he emerged into the daylight . aside from a few startled glances at the mismatched couple emerging from the tiny door in the foundation of palazzo vecchio , nobody gave them a second look . within seconds , langdon and sienna were moving east , swallowed up by the crowd . the man in the plume paris eyeglasses picked at his bleeding skin as he snaked through the crowd , keeping a safe distance behind robert langdon and sienna brooks . despite their clever disguises , he had spotted them emerging from the tiny door on the via della ninna and had immediately known who they were . he had tailed them only a few blocks before he got winded , his chest aching acutely , forcing him to take shallow breaths . he felt like he ’ d been punched in the sternum . gritting his teeth against the pain , he forced his attention back to langdon and sienna as he continued to follow them through the streets of florence . chapter 50 the morning sun had fully  ...

# %% [markdown]
# # Accuracy Analysis

# %%
original_chapter = chapter_other_text
filled_chapter = filled_chapter

# %%
original_tokens = word_tokenize(original_chapter)
filled_tokens = word_tokenize(filled_chapter)

# %%
matching_words = sum(1 for orig, filled in zip(original_tokens, filled_tokens) if orig == filled)

# %%
accuracy_percentage = (matching_words / len(original_tokens)) * 100

print("Accuracy Percentage:", accuracy_percentage)
# Out:
# Accuracy Percentage: 21.25124131082423
